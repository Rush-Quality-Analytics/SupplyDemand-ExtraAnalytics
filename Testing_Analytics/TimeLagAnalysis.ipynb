# %%
import plotly.express as px
from scipy.stats import binom
import pandas as pd
import csv
import numpy as np
import datetime
import re
import warnings
import sys
from scipy.optimize import curve_fit
from math import pi
from scipy import stats
from scipy.stats import lognorm
import plotly.graph_objects as go

pd.set_option('display.max_columns', None)

# %%
exclude = ['Recovered', 'Grand Princess', 'Diamond Princess', 'American Samoa', 'US', 
           'American Samoa', 'Northern Mariana Islands', 'Puerto Rico', 'Guam', 
           'Virgin Islands']

df0 = pd.read_csv('data/COVID-TESTING-DF.txt', sep='\t')
df0 = df0.loc[~df0['Province_State'].isin(exclude)]
states = df0['Province_State'].tolist()
JH_dates = df0['date'].tolist()

states_df = pd.read_csv('data/StatePops.csv', sep=',')
states_df = states_df.loc[~states_df['Province/State'].isin(exclude)]

fits_df = pd.read_pickle('data/model_results_dataframe.pkl')
fits_df = fits_df[fits_df['model'] == 'Quadratic'] 
fits_df = fits_df[fits_df['label'] == 'Current forecast']

AA_df = pd.read_csv('data/African_American.csv', sep=',')
AA_df = AA_df.loc[~AA_df['State'].isin(exclude)]

Poverty_df = pd.read_csv('data/Poverty.csv', sep=',')
Poverty_df = Poverty_df.loc[~Poverty_df['State'].isin(exclude)]

# %%
exclude_abbv = ['AS', 'VI', 'MP', 'GU', 'PR']
Atlantic_df = pd.read_csv('https://raw.githubusercontent.com/COVID19Tracking/covid-tracking-data/master/data/states_daily_4pm_et.csv', sep=',')
Atlantic_df.drop(['hash', 'dateChecked', 'fips', 'posNeg'], axis=1, inplace=True)
Atlantic_df = Atlantic_df.loc[~Atlantic_df['state'].isin(exclude_abbv)]
state_abvs = Atlantic_df['state'].tolist()

# %%
dates = Atlantic_df['date'].tolist()
dates_reformat = []
for d1 in dates:
    d2 = datetime.datetime.strptime(str(d1), '%Y%m%d')
    d2 = d2.strftime("%m/%d/%y")
    dates_reformat.append(d2)
    
Atlantic_df['formatted_dates'] = dates_reformat
Atlantic_df['UniqueRow'] = Atlantic_df['formatted_dates'] + '-' + Atlantic_df['state']

# %%
pop_sizes = []
colors = []
quadratic_r2s = []
AA_pop_tot = []
AA_pop_per = []
per_poor = []
unique_rows = []
delta_testing_rate = []
for i, state in enumerate(states):
    
    df_sub = df0[df0['Province_State'] == state]
    testing_rate = df_sub['Testing_Rate'].tolist()
    
    x = list(range(len(testing_rate)))
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, testing_rate)
    delta_testing_rate.append(slope)

    state_abv = states_df[states_df['Province/State'] == state]['Abbreviation'].iloc[0]
    u_row = JH_dates[i] + '-' + state_abv
    unique_rows.append(u_row)
    
    pop_size = states_df[states_df['Province/State'] == state].PopSize.iloc[0]
    pop_sizes.append(pop_size)
    
    r2 = fits_df[fits_df['focal_loc'] == state]['obs_pred_r2'].iloc[0]
    quadratic_r2s.append(r2)
    
    black_pop = AA_df[AA_df['State'] == state]['BlackTotal'].iloc[0]
    AA_pop_tot.append(black_pop)
    
    black_pop_per = AA_df[AA_df['State'] == state]['BlackPerc'].iloc[0]
    AA_pop_per.append(black_pop_per)
    
    poor = Poverty_df[Poverty_df['State'] == state]['2017_2018_avg'].iloc[0]
    per_poor.append(poor)
    
    if state == 'Illinois':
        colors.append('#FECB52')
    else:
        colors.append('#636EFA')
        
    
df0['PopSize'] = pop_sizes
df0['color'] = colors
df0['quadratic'] = quadratic_r2s
df0['BlackTotal'] = AA_pop_tot
df0['%Black'] = AA_pop_per
df0['%Poor'] = per_poor
df0['UniqueRow'] = unique_rows
df0['DeltaTestingRate'] = delta_testing_rate

# %%
main_df = pd.merge(df0, Atlantic_df, on='UniqueRow')
main_df.tail(10)
main_df.columns = main_df.columns.str.replace('date_x','date')

# %%
main_df['sqrt_PopSize'] = np.sqrt(main_df['PopSize'].tolist()).tolist()
main_df['Positives per capita'] = main_df.positive/main_df.PopSize
main_df['Negatives per capita'] = main_df.negative/main_df.PopSize
main_df['Percent positive'] = np.round(100 * main_df.positive/main_df.totalTestResults, 2)
main_df['Tests per capita'] = main_df.People_Tested/main_df.PopSize

main_df['log_PopSize'] = np.log10(main_df['PopSize'])
main_df['log_People_Tested'] = np.log10(main_df['People_Tested'])
main_df['log_Confirmed'] = np.log10(main_df['Confirmed'])
main_df['log_negative'] = np.log10(main_df['negative'])
main_df['log_positive'] = np.log10(main_df['positive'])
main_df['log_hospitalizedCurrently'] = np.log10(main_df['hospitalizedCurrently'])
main_df['log_inIcuCurrently'] = np.log10(main_df['inIcuCurrently'])

try:
    main_df.drop(['Unnamed: 0'], axis=1, inplace=True)
except:
    pass
main_df.head(10)
# Out:
#          Province_State      date  Confirmed  Deaths  Recovered  \
# 0               Alabama  04/12/20       3563      93        NaN
# 1                Alaska  04/12/20        272       8       66.0
# 2               Arizona  04/12/20       3542     115        NaN
# 3              Arkansas  04/12/20       1280      27      367.0
# 4            California  04/12/20      22795     640        NaN
# 5              Colorado  04/12/20       7307     289        NaN
# 6           Connecticut  04/12/20      12035     554        NaN
# 7              Delaware  04/12/20       1625      35      191.0
# 8  District of Columbia  04/12/20       1875      50      493.0
# 9               Florida  04/12/20      19895     461        NaN
#
#    Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 0      75.988020        21583.0                437.0        2.610160
# 1      45.504049         8038.0                 31.0        2.941176
# 2      48.662422        42109.0                  NaN        3.246753
# 3      49.439423        19722.0                130.0        2.109375
# 4      58.137726       190328.0               5234.0        2.812020
# 5     128.943729        34873.0               1376.0        3.955112
# 6     337.560483        41220.0               1654.0        4.603241
# 7     166.878217        11103.0                190.0        2.153846
# 8     265.675190        10640.0                  NaN        2.666667
# 9      93.700227       182753.0               2772.0        2.317165
#
#    Testing_Rate  Hospitalization_Rate   PopSize    color  quadratic  \
# 0    460.300152             12.264945   4903185  #636EFA   0.991651
# 1   1344.711576             11.397059    731545  #636EFA   0.973847
# 2    578.522286                   NaN   7278717  #636EFA   0.995076
# 3    761.753354             10.156250   3017804  #636EFA   0.992340
# 4    485.423869             22.961176  39512223  #636EFA   0.996806
# 5    615.389991             18.831258   5758736  #636EFA   0.996677
# 6   1156.148159             13.743249   3565287  #636EFA   0.988911
# 7   1140.214672             11.692308    973764  #636EFA   0.997342
# 8   1507.618148                   NaN    705749  #636EFA   0.996577
# 9    860.718651             13.933149  21477737  #636EFA   0.979362
#
#    BlackTotal  %Black  %Poor    UniqueRow  DeltaTestingRate    date_y state  \
# 0     1285737  0.2643   15.6  04/12/20-AL         77.454959  20200412    AL
# 1       22817  0.0309   12.6  04/12/20-AK        121.101855  20200412    AK
# 2      286614  0.0413   13.2  04/12/20-AZ         29.730895  20200412    AZ
# 3      458536  0.1533   15.4  04/12/20-AR         67.132028  20200412    AR
# 4     2164519  0.0553   12.0  04/12/20-CA         71.091397  20200412    CA
# 5      216732  0.0392    9.0  04/12/20-CO         40.005573  20200412    CO
# 6      351817  0.0982   10.4  04/12/20-CT         84.568088  20200412    CT
# 7      204665  0.2156    8.1  04/12/20-DE         64.008594  20200412    DE
# 8      315281  0.4606   14.3  04/12/20-DC         87.204680  20200412    DC
# 9     3167011  0.1538   13.5  04/12/20-FL         57.903213  20200412    FL
#
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0    3525.0   18058.0      NaN                    NaN                   437.0
# 1     272.0    7766.0      NaN                    NaN                    31.0
# 2    3539.0   38570.0      NaN                    NaN                     NaN
# 3    1280.0   18442.0      NaN                   74.0                   130.0
# 4   21794.0  168534.0  13200.0                 5234.0                     NaN
# 5    6893.0   27980.0      NaN                  822.0                  1376.0
# 6   12035.0   29185.0      NaN                 1654.0                     NaN
# 7    1479.0    9624.0      NaN                  190.0                     NaN
# 8    1875.0    8765.0      NaN                    NaN                     NaN
# 9   19355.0  163398.0   1297.0                    NaN                  2772.0
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0             NaN            189.0                    NaN
# 1             NaN              NaN                    NaN
# 2             NaN              NaN                    NaN
# 3             NaN             43.0                   30.0
# 4          1539.0              NaN                    NaN
# 5             NaN              NaN                    NaN
# 6             NaN              NaN                    NaN
# 7             NaN              NaN                    NaN
# 8             NaN              NaN                    NaN
# 9             NaN              NaN                    NaN
#
#    onVentilatorCumulative  recovered dataQualityGrade     lastUpdateEt  death  \
# 0                   119.0        NaN              NaN  4/12/2020 00:00   93.0
# 1                     NaN       66.0              NaN  4/12/2020 14:50    8.0
# 2                     NaN        NaN              NaN  4/12/2020 00:00  115.0
# 3                    39.0      367.0              NaN  4/12/2020 11:33   27.0
# 4                     NaN        NaN              NaN  4/11/2020 00:00  651.0
# 5                     NaN        NaN              NaN  4/11/2020 00:00  274.0
# 6                     NaN        NaN              NaN  4/12/2020 16:00  554.0
# 7                     NaN      191.0              NaN  4/11/2020 13:30   33.0
# 8                     NaN      493.0              NaN  4/11/2020 00:00   50.0
# 9                     NaN        NaN              NaN  4/12/2020 11:23  465.0
#
#    hospitalized   total  totalTestResults  deathIncrease  \
# 0         437.0   21583             21583            2.0
# 1          31.0    8038              8038            0.0
# 2           NaN   42109             42109            7.0
# 3         130.0   19722             19722            3.0
# 4           NaN  203528            190328           42.0
# 5        1376.0   34873             34873           24.0
# 6           NaN   41220             41220           60.0
# 7           NaN   11103             11103            0.0
# 8           NaN   10640             10640            3.0
# 9        2772.0  184050            182753           27.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                  35.0               0.0             334.0
# 1                   0.0             291.0              15.0
# 2                   0.0            1433.0             146.0
# 3                   0.0            1090.0              54.0
# 4                   0.0           15930.0            2322.0
# 5                  64.0            1837.0             383.0
# 6                   0.0             864.0             525.0
# 7                   0.0               0.0               0.0
# 8                   0.0             504.0              97.0
# 9                 111.0            8959.0             861.0
#
#    totalTestResultsIncrease formatted_dates  sqrt_PopSize  \
# 0                     334.0        04/12/20   2214.313663
# 1                     306.0        04/12/20    855.304040
# 2                    1579.0        04/12/20   2697.909746
# 3                    1144.0        04/12/20   1737.182777
# 4                   18252.0        04/12/20   6285.874879
# 5                    2220.0        04/12/20   2399.736652
# 6                    1389.0        04/12/20   1888.196759
# 7                       0.0        04/12/20    986.794811
# 8                     601.0        04/12/20    840.088686
# 9                    9820.0        04/12/20   4634.407945
#
#    Positives per capita  Negatives per capita  Percent positive  \
# 0              0.000719              0.003683             16.33
# 1              0.000372              0.010616              3.38
# 2              0.000486              0.005299              8.40
# 3              0.000424              0.006111              6.49
# 4              0.000552              0.004265             11.45
# 5              0.001197              0.004859             19.77
# 6              0.003376              0.008186             29.20
# 7              0.001519              0.009883             13.32
# 8              0.002657              0.012419             17.62
# 9              0.000901              0.007608             10.59
#
#    Tests per capita  log_PopSize  log_People_Tested  log_Confirmed  \
# 0          0.004402     6.690478           4.334112       3.551816
# 1          0.010988     5.864241           3.905148       2.434569
# 2          0.005785     6.862055           4.624375       3.549249
# 3          0.006535     6.479691           4.294951       3.107210
# 4          0.004817     7.596731           5.279503       4.357840
# 5          0.006056     6.760327           4.542489       3.863739
# 6          0.011561     6.552094           4.615108       4.080446
# 7          0.011402     5.988454           4.045440       3.210853
# 8          0.015076     5.848650           4.026942       3.273001
# 9          0.008509     7.331989           5.261865       4.298744
#
#    log_negative  log_positive  log_hospitalizedCurrently  log_inIcuCurrently  \
# 0      4.256670      3.547159                        NaN                 NaN
# 1      3.890197      2.434569                        NaN                 NaN
# 2      4.586250      3.548881                        NaN                 NaN
# 3      4.265808      3.107210                   1.869232                 NaN
# 4      5.226688      4.338337                   3.718834            3.187239
# 5      4.446848      3.838408                   2.914872                 NaN
# 6      4.465160      4.080446                   3.218536                 NaN
# 7      3.983356      3.169968                   2.278754                 NaN
# 8      3.942752      3.273001                        NaN                 NaN
# 9      5.213247      4.286793                        NaN                 NaN
#
#    testing_rate_incident_rate_ratio
# 0                          6.057536
# 1                         29.551471
# 2                         11.888481
# 3                         15.407813
# 4                          8.349550
# 5                          4.772547
# 6                          3.425010
# 7                          6.832615
# 8                          5.674667
# 9                          9.185876

# %%
fig = px.line(main_df, x="date", y="Confirmed", color="state",
              line_group="state", hover_name="state")

fig.update_xaxes(title_font=dict(size=22, family='Arial', color='black'))
fig.update_yaxes(title_font=dict(size=22, family='Arial', color='black'))
fig.show()
# Out:
# <div>
#
#
#             <div id="9f0ae86f-e227-4831-a54e-c21ca0c0f855" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f0ae86f-e227-4831-a54e-c21ca0c0f855")) {
#                     Plotly.newPlot(
#                         '9f0ae86f-e227-4831-a54e-c21ca0c0f855',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AL<br>date=%{x}<br>Confirmed=%{y}", "hovertext": ["AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL"], "legendgroup": "AL", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "AL", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [3563, 3734, 3953, 4075, 4345, 4571, 4712, 4888, 5079, 5317, 5593, 5832, 6026, 6026, 6421, 6539, 6750, 6912, 7088, 7294, 7611, 7888, 8112, 8437, 8691, 9046], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AK<br>date=%{x}<br>Confirmed=%{y}", "hovertext": ["AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK"], "legendgroup": "AK", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "AK", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [272, 277, 285, 293, 300, 309, 314, 319, 321, 329, 335, 337, 339, 339, 340, 345, 351, 355, 355, 364, 365, 368, 370, 371, 372, 374], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AZ<br>date=%{x}<br>Confirmed=%{y}", "hovertext": ["AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ"], "legendgroup": "AZ", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "AZ", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [3542, 3705, 3809, 3964, 4237, 4511, 4724, 4933, 5068, 5256, 5473, 5772, 6045, 6286, 6534, 6725, 6955, 7209, 7655, 7969, 8364, 8640, 8924, 9305, 9707, 9945], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AR<br>date=%{x}<br>Confirmed=%{y}", "hovertext": ["AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR"], "legendgroup": "AR", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "AR", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [1280, 1410, 1498, 1569, 1620, 1695, 1744, 1781, 1973, 1990, 2276, 2599, 2810, 2911, 3001, 3069, 3127, 3193, 3281, 3337, 3372, 3437, 3491, 3525, 3611, 3703], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=CA<br>date=%{x}<br>Confirmed=%{y}", "hovertext": ["CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA" ...

# %%
fig = px.line(main_df, x="date", y="People_Hospitalized", color="state",
              line_group="state", hover_name="state")

fig.update_xaxes(title_font=dict(size=22, family='Arial', color='black'))
fig.update_yaxes(title_font=dict(size=22, family='Arial', color='black'))
fig.show()
# Out:
# <div>
#
#
#             <div id="8f0858f7-d43b-42ba-8dd0-e105a8e3b780" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f0858f7-d43b-42ba-8dd0-e105a8e3b780")) {
#                     Plotly.newPlot(
#                         '8f0858f7-d43b-42ba-8dd0-e105a8e3b780',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AL<br>date=%{x}<br>People_Hospitalized=%{y}", "hovertext": ["AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL"], "legendgroup": "AL", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "AL", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [437.0, 457.0, 493.0, 525.0, 553.0, 594.0, 620.0, 641.0, 641.0, 699.0, 730.0, 768.0, 769.0, 839.0, 845.0, 872.0, 911.0, 945.0, 978.0, 1008.0, 1023.0, 1035.0, 1064.0, 1107.0, 1158.0, 1178.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AK<br>date=%{x}<br>People_Hospitalized=%{y}", "hovertext": ["AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK"], "legendgroup": "AK", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "AK", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [31.0, 32.0, 32.0, 34.0, 35.0, 36.0, 39.0, 37.0, 46.0, 42.0, 39.0, 42.0, 36.0, 32.0, 14.0, 10.0, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AZ<br>date=%{x}<br>People_Hospitalized=%{y}", "hovertext": ["AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ"], "legendgroup": "AZ", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "AZ", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [null, 525.0, 580.0, 590.0, 578.0, 566.0, 566.0, 631.0, 637.0, 637.0, 664.0, 699.0, 984.0, 1022.0, 1037.0, 1051.0, 1095.0, 1131.0, 1169.0, 1203.0, 1339.0, 1348.0, 1357.0, 1397.0, 1430.0, 1449.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>state=AR<br>date=%{x}<br>People_Hospitalized=%{y}", "hovertext": ["AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AR"], "legendgroup": "AR", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "AR", "showlegend": true, "type": "scattergl", "x": ["04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20", "04/23/20", "04/24/20", "04/25/20", "04/26/20", "04/27/20", "04/28/20", "04/29/20", "04/30/20", "05/01/20", "05/02/20", "05/03/20", "05/04/20", "05/05/20", "05/06/20", "05/07/20"], "xaxis": "x", "y": [130.0, 130.0, 130.0, 130.0, 85.0, 83.0, 291.0, 291.0, 291.0, 291.0, 291.0, 291.0, 291.0, 291.0, 291.0, 109.0, null, 389.0, 402.0, 414.0, 414.0, 427.0, 438.0, 453.0, 453.0, 462.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</ ...
